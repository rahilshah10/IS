# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Make plots larger
plt.rcParams['figure.figsize'] = (15, 9)

# %%
ds = pd.read_excel("database.xlsx")
print(ds)
# Out:
#         UNIQUE KEY       DATE      TIME        BOROUGH  ZIP CODE   LATITUDE  \
# 0          3146911 2015-01-01  00:20:00         QUEENS   11358.0  40.751847
# 1          3146180 2015-01-01  00:20:00            NaN       NaN  40.771289
# 2          3146384 2015-01-01  00:21:00       BROOKLYN   11205.0  40.689445
# 3          3146013 2015-01-01  00:30:00       BROOKLYN   11213.0  40.673845
# 4          3146120 2015-01-01  00:33:00            NaN       NaN        NaN
# 5          3145968 2015-01-01  00:51:00       BROOKLYN   11203.0  40.656684
# 6          3146102 2015-01-01  10:00:00         QUEENS   11105.0  40.776519
# 7          3146344 2015-01-01  10:05:00       BROOKLYN   11203.0  40.657281
# 8          3145900 2015-01-01  10:06:00      MANHATTAN   10024.0  40.787223
# 9          3145960 2015-01-01  10:10:00       BROOKLYN   11223.0  40.593323
# 10         3145881 2015-01-01  10:15:00      MANHATTAN   10036.0  40.762184
# ...

# %%
ds.head
# Out:
# <bound method NDFrame.head of         UNIQUE KEY       DATE      TIME        BOROUGH  ZIP CODE   LATITUDE  \
# 0          3146911 2015-01-01  00:20:00         QUEENS   11358.0  40.751847
# 1          3146180 2015-01-01  00:20:00            NaN       NaN  40.771289
# 2          3146384 2015-01-01  00:21:00       BROOKLYN   11205.0  40.689445
# 3          3146013 2015-01-01  00:30:00       BROOKLYN   11213.0  40.673845
# 4          3146120 2015-01-01  00:33:00            NaN       NaN        NaN
# 5          3145968 2015-01-01  00:51:00       BROOKLYN   11203.0  40.656684
# 6          3146102 2015-01-01  10:00:00         QUEENS   11105.0  40.776519
# 7          3146344 2015-01-01  10:05:00       BROOKLYN   11203.0  40.657281
# 8          3145900 2015-01-01  10:06:00      MANHATTAN   10024.0  40.787223
# 9          3145960 2015-01-01  10:10:00       BROOKLYN   11223.0  40.593323
# 10         3145881 2015-01-01  10:15:00      MANHATTAN   10036.0  40.762184
# ...

# %%
ds.describe
# Out:
# <bound method NDFrame.describe of         UNIQUE KEY       DATE      TIME        BOROUGH  ZIP CODE   LATITUDE  \
# 0          3146911 2015-01-01  00:20:00         QUEENS   11358.0  40.751847
# 1          3146180 2015-01-01  00:20:00            NaN       NaN  40.771289
# 2          3146384 2015-01-01  00:21:00       BROOKLYN   11205.0  40.689445
# 3          3146013 2015-01-01  00:30:00       BROOKLYN   11213.0  40.673845
# 4          3146120 2015-01-01  00:33:00            NaN       NaN        NaN
# 5          3145968 2015-01-01  00:51:00       BROOKLYN   11203.0  40.656684
# 6          3146102 2015-01-01  10:00:00         QUEENS   11105.0  40.776519
# 7          3146344 2015-01-01  10:05:00       BROOKLYN   11203.0  40.657281
# 8          3145900 2015-01-01  10:06:00      MANHATTAN   10024.0  40.787223
# 9          3145960 2015-01-01  10:10:00       BROOKLYN   11223.0  40.593323
# 10         3145881 2015-01-01  10:15:00      MANHATTAN   10036.0  40.762184
# ...

# %%
ds.head
# Out:
# <bound method NDFrame.head of         UNIQUE KEY       DATE      TIME        BOROUGH  ZIP CODE   LATITUDE  \
# 0          3146911 2015-01-01  00:20:00         QUEENS   11358.0  40.751847
# 1          3146180 2015-01-01  00:20:00            NaN       NaN  40.771289
# 2          3146384 2015-01-01  00:21:00       BROOKLYN   11205.0  40.689445
# 3          3146013 2015-01-01  00:30:00       BROOKLYN   11213.0  40.673845
# 4          3146120 2015-01-01  00:33:00            NaN       NaN        NaN
# 5          3145968 2015-01-01  00:51:00       BROOKLYN   11203.0  40.656684
# 6          3146102 2015-01-01  10:00:00         QUEENS   11105.0  40.776519
# 7          3146344 2015-01-01  10:05:00       BROOKLYN   11203.0  40.657281
# 8          3145900 2015-01-01  10:06:00      MANHATTAN   10024.0  40.787223
# 9          3145960 2015-01-01  10:10:00       BROOKLYN   11223.0  40.593323
# 10         3145881 2015-01-01  10:15:00      MANHATTAN   10036.0  40.762184
# ...

# %%
ds.tail
# Out:
# <bound method NDFrame.tail of         UNIQUE KEY       DATE      TIME        BOROUGH  ZIP CODE   LATITUDE  \
# 0          3146911 2015-01-01  00:20:00         QUEENS   11358.0  40.751847
# 1          3146180 2015-01-01  00:20:00            NaN       NaN  40.771289
# 2          3146384 2015-01-01  00:21:00       BROOKLYN   11205.0  40.689445
# 3          3146013 2015-01-01  00:30:00       BROOKLYN   11213.0  40.673845
# 4          3146120 2015-01-01  00:33:00            NaN       NaN        NaN
# 5          3145968 2015-01-01  00:51:00       BROOKLYN   11203.0  40.656684
# 6          3146102 2015-01-01  10:00:00         QUEENS   11105.0  40.776519
# 7          3146344 2015-01-01  10:05:00       BROOKLYN   11203.0  40.657281
# 8          3145900 2015-01-01  10:06:00      MANHATTAN   10024.0  40.787223
# 9          3145960 2015-01-01  10:10:00       BROOKLYN   11223.0  40.593323
# 10         3145881 2015-01-01  10:15:00      MANHATTAN   10036.0  40.762184
# ...

# %%
ds.info
# Out:
# <bound method DataFrame.info of         UNIQUE KEY       DATE      TIME        BOROUGH  ZIP CODE   LATITUDE  \
# 0          3146911 2015-01-01  00:20:00         QUEENS   11358.0  40.751847
# 1          3146180 2015-01-01  00:20:00            NaN       NaN  40.771289
# 2          3146384 2015-01-01  00:21:00       BROOKLYN   11205.0  40.689445
# 3          3146013 2015-01-01  00:30:00       BROOKLYN   11213.0  40.673845
# 4          3146120 2015-01-01  00:33:00            NaN       NaN        NaN
# 5          3145968 2015-01-01  00:51:00       BROOKLYN   11203.0  40.656684
# 6          3146102 2015-01-01  10:00:00         QUEENS   11105.0  40.776519
# 7          3146344 2015-01-01  10:05:00       BROOKLYN   11203.0  40.657281
# 8          3145900 2015-01-01  10:06:00      MANHATTAN   10024.0  40.787223
# 9          3145960 2015-01-01  10:10:00       BROOKLYN   11223.0  40.593323
# 10         3145881 2015-01-01  10:15:00      MANHATTAN   10036.0  40.762184
# ...
